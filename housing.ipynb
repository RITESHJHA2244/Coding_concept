# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data points (x, y)
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Number of points
n = len(x)

# Step 1: Calculate means of x and y
mean_x = np.mean(x)
mean_y = np.mean(y)

# Step 2: Calculate slope (m) and intercept (c) using calculus-derived formulas
# m = Σ((x - mean_x)(y - mean_y)) / Σ((x - mean_x)^2)
numerator = np.sum((x - mean_x) * (y - mean_y))
denominator = np.sum((x - mean_x) ** 2)
m = numerator / denominator

# c = mean_y - m * mean_x
c = mean_y - m * mean_x

print(f"Slope (m): {m:.4f}")
print(f"Intercept (c): {c:.4f}")

# Step 3: Predicted y values (y = mx + c)
y_pred = m * x + c

# Step 4: Plotting the data and the best fit line
plt.scatter(x, y, color='blue', label='Data Points')
plt.plot(x, y_pred, color='red', label='Best Fit Line')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Best Fit Line using Least Squares (Calculus)')
plt.grid(True)
plt.show()
# Out:
# Slope (m): 0.6000
# Intercept (c): 2.2000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Read CSV without header and set column names manually
df = pd.read_csv("housingprice 2.csv", header=None)
df.columns = ['A', 'B']  # Manually assign correct names

# Step 2: Extract x and y
x = df['A'].values
y = df['B'].values

# Step 3: Compute means
mean_x = np.mean(x)
mean_y = np.mean(y)

# Step 4: Compute slope (m) and intercept (c)
numerator = np.sum((x - mean_x) * (y - mean_y))
denominator = np.sum((x - mean_x) ** 2)
m = numerator / denominator
c = mean_y - m * mean_x

# Step 5: Predict y values
y_pred = m * x + c

# Step 6: Plot data and regression line
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', label='Actual Data',marker='.')
plt.plot(x, y_pred, color='red', label=f'Best Fit Line: y = {m:.2f}x + {c:.2f}')
plt.xlabel('A (x)')
plt.ylabel('B (y)')
plt.title('Best Fit Line from CSV')
plt.legend()
plt.grid(True)
plt.show()
